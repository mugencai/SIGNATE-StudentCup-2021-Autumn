# %%
import os
import sys
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
import warnings
warnings.simplefilter('ignore')

# %%
pd.set_option('display.max_columns', 500) # 最大显示列数500
pd.set_option('display.max_rows', 500) # 最大显示行数500

# %%
# pip install lightgbm --install-option=--gpu

# %%
pip install bayesian-optimization
# Out:
# Requirement already satisfied: bayesian-optimization in c:\programdata\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: scikit-learn>=0.18.0 in c:\programdata\anaconda3\lib\site-packages (from bayesian-optimization) (0.23.2)
# Requirement already satisfied: numpy>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from bayesian-optimization) (1.19.2)
# Requirement already satisfied: scipy>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from bayesian-optimization) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (0.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 数据预处理

# %%
status = pd.read_csv('status.csv') 
status["date"] = pd.to_datetime(status[["year", "month", "day"]])


station = pd.read_csv("station.csv")

station = station.drop(["installation_date",], axis=1)

weather = pd.read_csv('weather.csv') 
weather['date'] = pd.to_datetime(weather['date'],format="%Y-%m-%d")
weather = weather.drop(["events",                                     
                        "max_temperature","min_temperature","mean_temperature",
                        "max_dew_point","min_dew_point","mean_dew_point",
                        "max_humidity","min_humidity","mean_humidity",
                        "max_sea_level_pressure","mean_sea_level_pressure","min_sea_level_pressure",
                        "max_visibility","min_visibility",
                        "max_wind_Speed",
                        "cloud_cover",
                        "wind_dir_degrees",
                        
#                         "mean_visibility",
#                         "mean_wind_speed",
                        
#                         "precipitation",
                        
                       ], axis=1)

# %%
#通过date新增“weekday”列
#“weekday”列后续处理参照“チュートリアル第二弾”
#曜日を追加するための関数を定義
def get_week(dt):
    w_list = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    return(w_list[dt.weekday()])
status["weekday"] = status["date"].apply(get_week)

status.head(2)
# Out:
#    id  year  month  day  hour  station_id  bikes_available  predict  \
# 0   0  2013      9    1     0           0             11.0        0
# 1   1  2013      9    1     1           0             11.0        0
#
#         date weekday
# 0 2013-09-01  Sunday
# 1 2013-09-01  Sunday

# %%
station.head(2)
# Out:
#    station_id       lat       long  dock_count   city
# 0           0  37.32973 -121.90178          27  city1
# 1           1  37.33070 -121.88898          15  city1

# %%
#通过"date"列连接status与weather文件（注意处理一下status“date”列的时分秒）
#注意后续drop掉“events”列
weather.head(2)
# Out:
#         date  mean_visibility  mean_wind_speed  precipitation
# 0 2013-09-01               10                4            0.0
# 1 2013-09-02               10                4            0.0

# %%
_ = pd.merge(status, station, on = "station_id")
_ = pd.merge(_, weather, on = "date")

# _['installation_date'] = pd.to_datetime(_['installation_date'],format="%m/%d/%Y")

# %%
_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1226400 entries, 0 to 1226399
# Data columns (total 17 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   id               1226400 non-null  int64
#  1   year             1226400 non-null  int64
#  2   month            1226400 non-null  int64
#  3   day              1226400 non-null  int64
#  4   hour             1226400 non-null  int64
#  5   station_id       1226400 non-null  int64
#  6   bikes_available  809995 non-null   float64
#  7   predict          1226400 non-null  int64
#  8   date             1226400 non-null  datetime64[ns]
#  9   weekday          1226400 non-null  object
#  10  lat              1226400 non-null  float64
#  11  long             1226400 non-null  float64
#  12  dock_count       1226400 non-null  int64
#  13  city             1226400 non-null  object
#  14  mean_visibility  1226400 non-null  int64
#  15  mean_wind_speed  1226400 non-null  int64
#  16  precipitation    1226400 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(10), object(2)
# memory usage: 168.4+ MB

# %%
_.head(2)
# Out:
#    id  year  month  day  hour  station_id  bikes_available  predict  \
# 0   0  2013      9    1     0           0             11.0        0
# 1   1  2013      9    1     1           0             11.0        0
#
#         date weekday       lat       long  dock_count   city  mean_visibility  \
# 0 2013-09-01  Sunday  37.32973 -121.90178          27  city1               10
# 1 2013-09-01  Sunday  37.32973 -121.90178          27  city1               10
#
#    mean_wind_speed  precipitation
# 0                4            0.0
# 1                4            0.0

# %%
_.shape
# Out:
# (1226400, 17)

# %%
#将"city"列转换为one-hot

#将date数据转字符串
# _["installation_date"] = _["installation_date"].dt.strftime('%Y-%m-%d')

#处理离散型的特征： 一次独热编码
_ = pd.get_dummies(_, dummy_na=False) #"Dummy_na=True"将"na"（缺失值）视为有效的特征值，并为其创建指示符特征

# %%
_.head(2)
# Out:
#    id  year  month  day  hour  station_id  bikes_available  predict  \
# 0   0  2013      9    1     0           0             11.0        0
# 1   1  2013      9    1     1           0             11.0        0
#
#         date       lat       long  dock_count  mean_visibility  \
# 0 2013-09-01  37.32973 -121.90178          27               10
# 1 2013-09-01  37.32973 -121.90178          27               10
#
#    mean_wind_speed  precipitation  weekday_Friday  weekday_Monday  \
# 0                4            0.0               0               0
# 1                4            0.0               0               0
#
#    weekday_Saturday  weekday_Sunday  weekday_Thursday  weekday_Tuesday  \
# 0                 0               1                 0                0
# 1                 0               1                 0                0
#
#    weekday_Wednesday  city_city1  city_city2  city_city3  city_city4  \
# 0                  0           1           0           0           0
# 1                  0           1           0           0           0
#
#    city_city5
# 0           0
# 1           0

# %%
train = _.loc[_["predict"] == 0]
test = _.loc[_["predict"] == 1]

# %%
train.shape
# Out:
# (1033200, 27)

# %%
train.head(2)
# Out:
#    id  year  month  day  hour  station_id  bikes_available  predict  \
# 0   0  2013      9    1     0           0             11.0        0
# 1   1  2013      9    1     1           0             11.0        0
#
#         date       lat       long  dock_count  mean_visibility  \
# 0 2013-09-01  37.32973 -121.90178          27               10
# 1 2013-09-01  37.32973 -121.90178          27               10
#
#    mean_wind_speed  precipitation  weekday_Friday  weekday_Monday  \
# 0                4            0.0               0               0
# 1                4            0.0               0               0
#
#    weekday_Saturday  weekday_Sunday  weekday_Thursday  weekday_Tuesday  \
# 0                 0               1                 0                0
# 1                 0               1                 0                0
#
#    weekday_Wednesday  city_city1  city_city2  city_city3  city_city4  \
# 0                  0           1           0           0           0
# 1                  0           1           0           0           0
#
#    city_city5
# 0           0
# 1           0

# %%
train.isna().any(axis=0)
#train["bikes_available"]里头有缺失值
# Out:
# id                   False
# year                 False
# month                False
# day                  False
# hour                 False
# station_id           False
# bikes_available       True
# predict              False
# date                 False
# lat                  False
# long                 False
# dock_count           False
# mean_visibility      False
# mean_wind_speed      False
# precipitation        False
# weekday_Friday       False
# weekday_Monday       False
# weekday_Saturday     False
# weekday_Sunday       False
# weekday_Thursday     False
# weekday_Tuesday      False
# weekday_Wednesday    False
# city_city1           False
# city_city2           False
# city_city3           False
# city_city4           False
# city_city5           False
# dtype: bool

# %%
test.isna().any(axis=0)
# Out:
# id                   False
# year                 False
# month                False
# day                  False
# hour                 False
# station_id           False
# bikes_available       True
# predict              False
# date                 False
# lat                  False
# long                 False
# dock_count           False
# mean_visibility      False
# mean_wind_speed      False
# precipitation        False
# weekday_Friday       False
# weekday_Monday       False
# weekday_Saturday     False
# weekday_Sunday       False
# weekday_Thursday     False
# weekday_Tuesday      False
# weekday_Wednesday    False
# city_city1           False
# city_city2           False
# city_city3           False
# city_city4           False
# city_city5           False
# dtype: bool

# %%
#删掉train里头的缺失值
train = train.dropna(subset = ["bikes_available"])
train.shape
# Out:
# (809995, 27)

# %%
#给train，test添加"yearmonth"新列以便后续拆解小test
df_m_s = train[train['month'] < 10].copy()
df_m_b = train[train['month'] >= 10].copy()
df_m_s['yearmonth'] = df_m_s['year'].astype(str) + ('0' + df_m_s['month'].astype(str))
df_m_b['yearmonth'] = df_m_b['year'].astype(str) + df_m_b['month'].astype(str)
train = pd.concat([df_m_s, df_m_b])

test = test.copy()
df_m_s = test[test['month'] < 10].copy()
df_m_b = test[test['month'] >= 10].copy()
df_m_s['yearmonth'] = df_m_s['year'].astype(str) + ('0' + df_m_s['month'].astype(str))
df_m_b['yearmonth'] = df_m_b['year'].astype(str) + df_m_b['month'].astype(str)
test = pd.concat([df_m_s, df_m_b])

# %%
train.head(2)
# Out:
#    id  year  month  day  hour  station_id  bikes_available  predict  \
# 0   0  2013      9    1     0           0             11.0        0
# 1   1  2013      9    1     1           0             11.0        0
#
#         date       lat       long  dock_count  mean_visibility  \
# 0 2013-09-01  37.32973 -121.90178          27               10
# 1 2013-09-01  37.32973 -121.90178          27               10
#
#    mean_wind_speed  precipitation  weekday_Friday  weekday_Monday  \
# 0                4            0.0               0               0
# 1                4            0.0               0               0
#
#    weekday_Saturday  weekday_Sunday  weekday_Thursday  weekday_Tuesday  \
# 0                 0               1                 0                0
# 1                 0               1                 0                0
#
#    weekday_Wednesday  city_city1  city_city2  city_city3  city_city4  \
# 0                  0           1           0           0           0
# 1                  0           1           0           0           0
#
#    city_city5 yearmonth
# 0           0    201309
# 1           0    201309

# %%
test.head(2)
# Out:
#           id  year  month  day  hour  station_id  bikes_available  predict  \
# 613201  8761  2014      9    1     1           0              NaN        1
# 613202  8762  2014      9    1     2           0              NaN        1
#
#              date       lat       long  dock_count  mean_visibility  \
# 613201 2014-09-01  37.32973 -121.90178          27               10
# 613202 2014-09-01  37.32973 -121.90178          27               10
#
#         mean_wind_speed  precipitation  weekday_Friday  weekday_Monday  \
# 613201                5            0.0               0               1
# 613202                5            0.0               0               1
#
#         weekday_Saturday  weekday_Sunday  weekday_Thursday  weekday_Tuesday  \
# 613201                 0               0                 0                0
# 613202                 0               0                 0                0
#
#         weekday_Wednesday  city_city1  city_city2  city_city3  city_city4  \
# 613201                  0           1           0           0           0
# 613202                  0           1           0           0           0
#
#         city_city5 yearmonth
# 613201           0    201409
# 613202           0    201409

# %%
#train年-月groupby
groupby = train.groupby("yearmonth").apply(lambda x: len(x)).reset_index()
groupby.columns = ["train_yearmonth","numbers"]
groupby = groupby.sort_values("train_yearmonth", ascending = True)
print(groupby["numbers"].sum())
groupby
# Out:
# 809995
#    train_yearmonth  numbers
# 0           201309    46080
# 1           201310    47616
# 2           201311    46080
# 3           201312    47664
# 4           201401    50083
# 5           201402    45900
# 6           201403    51336
# 7           201404    50196
# 8           201405    52080
# 9           201406    50400
# 10          201407    52080
# 11          201408    52080
# 12          201409    17500
# 13          201410    19180
# 14          201411    17500
# 15          201412    19180
# 16          201501    19180
# 17          201502    14140
# 18          201503    19180
# 19          201504    17500
# 20          201505    19180
# 21          201506    17500
# 22          201507    19180
# 23          201508    19180

# %%
#test年-月groupby
groupby = test.groupby("yearmonth").apply(lambda x: len(x)).reset_index()
groupby.columns = ["test_yearmonth","numbers"]
print(groupby["numbers"].sum())
groupby
# Out:
# 193200
#    test_yearmonth  numbers
# 0          201409    16100
# 1          201410    16100
# 2          201411    16100
# 3          201412    16100
# 4          201501    16100
# 5          201502    16100
# 6          201503    16100
# 7          201504    16100
# 8          201505    16100
# 9          201506    16100
# 10         201507    16100
# 11         201508    16100

# %% [markdown]
# # 训练+预测

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

cv_score = []
#预测201409时：验证集用201408的数据，训练集就用201407及其之前的数据，
#预测201410时：验证集用201409的数据，训练集就用201408及其之前的数据，依次类推
def train_predict(year_month):
    
    #train,validation,test sets
    if year_month == "201501":
        valid5 = train.loc[train["yearmonth"] == "201412"]
        train5 = train.loc[train["yearmonth"] < "201412"]
    else:
        valid5 = train.loc[train["yearmonth"] == str(int(year_month) - 1)]
        train5 = train.loc[train["yearmonth"] < str(int(year_month) - 1)]
    test5 = test.loc[test["yearmonth"] == year_month]
    
    train5 = train5.drop(["date", "id", "predict"], axis=1)
    valid5 = valid5.drop(["date", "id", "predict"], axis=1)
    print("train's shape: " + str(train5.shape))
    print("valid's shape: " + str(valid5.shape))

    
    # training
    X_train, X_test=train5.drop(["yearmonth", "bikes_available"], axis=1), valid5.drop(["yearmonth", "bikes_available"], axis=1)
    Y_train, Y_test=train5['bikes_available'], valid5['bikes_available']
    
    lgb_train=lgb.Dataset(X_train,Y_train)
    lgb_eval=lgb.Dataset(X_test,Y_test)
    params={
        'boosting': 'gbdt',
        'objective':'regression',
        'metric':'rmse',
        
        'learning_rate':0.001,
        
        'num_leaves': 128, 
        'max_depth': 18,
        
        
        'random_seed':42,
#         'subsample': 0.8, 
#         'max_bin': 196,
        
        'device': 'gpu',
    }

    evals_result = {}
    early_stopping_rounds = 5000
    model=lgb.train(params, lgb_train, 
                valid_names = ["train", "valid"],
                valid_sets=[lgb_train,lgb_eval],
                evals_result=evals_result, #以字典的形式存储验证结果
                verbose_eval=2000,  #打印log的间隔
                num_boost_round=20000, #迭代次数
                early_stopping_rounds=early_stopping_rounds,
               )
    
    #     print(evals_result)
    #     print(model.best_iteration)
    global cv_score
    if early_stopping_rounds == 0:
        cv_score.append(evals_result["valid"]["rmse"][-1])
    else:
        cv_score.append(evals_result["valid"]["rmse"][model.best_iteration - 1])
    #这里的“evals_result["valid"]["rmse"]”是从“print(evals_result)”中看出来的
    #print(cv_score)
    
    lgb.plot_metric(evals_result, metric=None, dataset_names=None, ax=None,
      xlim=None, ylim=None, title='YearMonth' + year_month +'_Metric during training',
      xlabel='Iterations', ylabel='auto', figsize=None, grid=True)
    
    
    #predict
    #test_id确保预测结果的顺序
    test_id = pd.DataFrame(test5["id"])
    test_id = test_id.reset_index()
    del test_id["index"]

    test_feature = test5.drop(["id", "predict", "bikes_available", "yearmonth", "date",], axis=1)
    test_label = model.predict(test_feature, num_iteration=model.best_iteration)
    test_label = pd.DataFrame(test_label)

    test_label = pd.concat([test_id, test_label], axis=1)
    return test_label,cv_score

# %%
def utils(year_month):
    if year_month == "201501":
        train_year_month, test_year_month = "201411", "201412"
    elif year_month == "201502":
        train_year_month, test_year_month = "201412", "201501"
    else:
        train_year_month, test_year_month = str(int(year_month) - 2), str(int(year_month) - 1)
        
    print("-----------------------------")
    print("Train: 201309 ～ " + train_year_month )
    print("Valid: " + test_year_month )
    print("Test:  " + str(int(year_month)) )

# %% [markdown]
#
#
#
# 通过for循环实现test的12个year_month
#
#     for x in range(4):
#         year_month = str(201409 + x)
#         print(year_month)
#     for x in range(1,9):
#         year_month = str(201500 + x)
#         print(year_month)

# %%
test_labels =[]
test_labels = pd.DataFrame(test_labels)
for x in range(4):
    year_month = str(201409 + x)
    utils(year_month)
    test_label, cv_score = train_predict(year_month)
    test_labels = pd.concat([test_labels, test_label])
    print(" ")
    

for x in range(1,9):
    year_month = str(201500 + x)
    utils(year_month)
    test_label, cv_score = train_predict(year_month)
    test_labels = pd.concat([test_labels, test_label])
    print(" ")
    
    
print("------------ " + " END" + " ------------")
# cv_score.remove(min(cv_score))  
# cv_score.remove(max(cv_score))  
cv_score = float(sum(cv_score))/len(cv_score) 
print ("CV: ", cv_score)
# Out:
# -----------------------------
# Train: 201309 ～ 201407
# Valid: 201408
# Test:  201409
# train's shape: (539515, 25)
# valid's shape: (52080, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 351
# [LightGBM] [Info] Number of data points in the train set: 539515, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 11 dense feature groups (6.17 MB) transferred to GPU in 0.007433 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.601260
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 2.88578	valid's rmse: 3.17936
# [4000]	train's rmse: 2.76095	valid's rmse: 3.16093
# [6000]	train's rmse: 2.70072	valid's rmse: 3.15939
# [8000]	train's rmse: 2.65221	valid's rmse: 3.15972
# Early stopping, best iteration is:
# [6421]	train's rmse: 2.6909	valid's rmse: 3.15854
#
# -----------------------------
# Train: 201309 ～ 201408
# Valid: 201409
# Test:  201410
# train's shape: (591595, 25)
# valid's shape: (17500, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 352
# [LightGBM] [Info] Number of data points in the train set: 591595, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 11 dense feature groups (6.77 MB) transferred to GPU in 0.007872 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.580480
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 2.91132	valid's rmse: 3.39298
# [4000]	train's rmse: 2.79437	valid's rmse: 3.35455
# [6000]	train's rmse: 2.73675	valid's rmse: 3.34039
# [8000]	train's rmse: 2.68547	valid's rmse: 3.33749
# [10000]	train's rmse: 2.64267	valid's rmse: 3.33461
# [12000]	train's rmse: 2.60395	valid's rmse: 3.335
# Early stopping, best iteration is:
# [10967]	train's rmse: 2.6244	valid's rmse: 3.33412
#
# -----------------------------
# Train: 201309 ～ 201409
# Valid: 201410
# Test:  201411
# train's shape: (609095, 25)
# valid's shape: (19180, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 353
# [LightGBM] [Info] Number of data points in the train set: 609095, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 11 dense feature groups (6.97 MB) transferred to GPU in 0.008074 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.572201
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 2.92593	valid's rmse: 3.72031
# [4000]	train's rmse: 2.80892	valid's rmse: 3.68967
# [6000]	train's rmse: 2.74786	valid's rmse: 3.69751
# Early stopping, best iteration is:
# [4397]	train's rmse: 2.79371	valid's rmse: 3.68681
#
# -----------------------------
# Train: 201309 ～ 201410
# Valid: 201411
# Test:  201412
# train's shape: (628275, 25)
# valid's shape: (17500, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 354
# [LightGBM] [Info] Number of data points in the train set: 628275, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 10 dense feature groups (7.19 MB) transferred to GPU in 0.007818 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.565499
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 2.94723	valid's rmse: 3.43902
# [4000]	train's rmse: 2.82988	valid's rmse: 3.38563
# [6000]	train's rmse: 2.77104	valid's rmse: 3.38339
# Early stopping, best iteration is:
# [4807]	train's rmse: 2.80152	valid's rmse: 3.38255
#
# -----------------------------
# Train: 201309 ～ 201411
# Valid: 201412
# Test:  201501
# train's shape: (645775, 25)
# valid's shape: (19180, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 355
# [LightGBM] [Info] Number of data points in the train set: 645775, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 10 dense feature groups (7.39 MB) transferred to GPU in 0.008165 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.562242
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 2.9604	valid's rmse: 3.68816
# [4000]	train's rmse: 2.84457	valid's rmse: 3.61699
# [6000]	train's rmse: 2.78293	valid's rmse: 3.61131
# [8000]	train's rmse: 2.72825	valid's rmse: 3.61382
# Early stopping, best iteration is:
# [6318]	train's rmse: 2.77292	valid's rmse: 3.6105
#
# -----------------------------
# Train: 201309 ～ 201412
# Valid: 201501
# Test:  201502
# train's shape: (664955, 25)
# valid's shape: (19180, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 364
# [LightGBM] [Info] Number of data points in the train set: 664955, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 10 dense feature groups (7.61 MB) transferred to GPU in 0.008308 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.563528
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 2.97749	valid's rmse: 3.47216
# [4000]	train's rmse: 2.85809	valid's rmse: 3.45684
# [6000]	train's rmse: 2.79523	valid's rmse: 3.45322
# Early stopping, best iteration is:
# [5528]	train's rmse: 2.80874	valid's rmse: 3.45288
#
# -----------------------------
# Train: 201309 ～ 201501
# Valid: 201502
# Test:  201503
# train's shape: (684135, 25)
# valid's shape: (14140, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 365
# [LightGBM] [Info] Number of data points in the train set: 684135, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 11 dense feature groups (7.83 MB) transferred to GPU in 0.008875 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.551983
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 2.98927	valid's rmse: 3.50838
# [4000]	train's rmse: 2.87052	valid's rmse: 3.42861
# [6000]	train's rmse: 2.80984	valid's rmse: 3.40318
# [8000]	train's rmse: 2.75831	valid's rmse: 3.39249
# [10000]	train's rmse: 2.70766	valid's rmse: 3.39363
# Early stopping, best iteration is:
# [8011]	train's rmse: 2.75804	valid's rmse: 3.39233
#
# -----------------------------
# Train: 201309 ～ 201502
# Valid: 201503
# Test:  201504
# train's shape: (698275, 25)
# valid's shape: (19180, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 366
# [LightGBM] [Info] Number of data points in the train set: 698275, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 11 dense feature groups (7.99 MB) transferred to GPU in 0.008893 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.544025
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 2.9972	valid's rmse: 3.64677
# [4000]	train's rmse: 2.87994	valid's rmse: 3.5739
# [6000]	train's rmse: 2.8186	valid's rmse: 3.52031
# [8000]	train's rmse: 2.76831	valid's rmse: 3.50754
# [10000]	train's rmse: 2.71867	valid's rmse: 3.50603
# [12000]	train's rmse: 2.68367	valid's rmse: 3.50012
# [14000]	train's rmse: 2.65284	valid's rmse: 3.49847
# Early stopping, best iteration is:
# [12960]	train's rmse: 2.66966	valid's rmse: 3.49783
#
# -----------------------------
# Train: 201309 ～ 201503
# Valid: 201504
# Test:  201505
# train's shape: (717455, 25)
# valid's shape: (17500, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 366
# [LightGBM] [Info] Number of data points in the train set: 717455, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 11 dense feature groups (8.21 MB) transferred to GPU in 0.009320 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.529699
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 3.01489	valid's rmse: 3.35223
# [4000]	train's rmse: 2.89686	valid's rmse: 3.27136
# [6000]	train's rmse: 2.83223	valid's rmse: 3.26462
# [8000]	train's rmse: 2.78285	valid's rmse: 3.2685
# Early stopping, best iteration is:
# [6627]	train's rmse: 2.81491	valid's rmse: 3.26324
#
# -----------------------------
# Train: 201309 ～ 201504
# Valid: 201505
# Test:  201506
# train's shape: (734955, 25)
# valid's shape: (19180, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 366
# [LightGBM] [Info] Number of data points in the train set: 734955, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 11 dense feature groups (8.41 MB) transferred to GPU in 0.008945 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.520719
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 3.02155	valid's rmse: 3.50548
# [4000]	train's rmse: 2.90597	valid's rmse: 3.45398
# [6000]	train's rmse: 2.84286	valid's rmse: 3.44416
# [8000]	train's rmse: 2.79432	valid's rmse: 3.44086
# [10000]	train's rmse: 2.75006	valid's rmse: 3.44352
# Early stopping, best iteration is:
# [8157]	train's rmse: 2.78995	valid's rmse: 3.44046
#
# -----------------------------
# Train: 201309 ～ 201505
# Valid: 201506
# Test:  201507
# train's shape: (754135, 25)
# valid's shape: (17500, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 367
# [LightGBM] [Info] Number of data points in the train set: 754135, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 11 dense feature groups (8.63 MB) transferred to GPU in 0.009389 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.506461
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 3.03268	valid's rmse: 3.50823
# [4000]	train's rmse: 2.91571	valid's rmse: 3.49592
# [6000]	train's rmse: 2.85535	valid's rmse: 3.50077
# Early stopping, best iteration is:
# [4980]	train's rmse: 2.88315	valid's rmse: 3.49093
#
# -----------------------------
# Train: 201309 ～ 201506
# Valid: 201507
# Test:  201508
# train's shape: (771635, 25)
# valid's shape: (19180, 25)
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 367
# [LightGBM] [Info] Number of data points in the train set: 771635, number of used features: 23
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3060, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 11 dense feature groups (8.83 MB) transferred to GPU in 0.010127 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score 8.495921
# Training until validation scores don't improve for 2000 rounds
# [2000]	train's rmse: 3.04281	valid's rmse: 3.33746
# [4000]	train's rmse: 2.92616	valid's rmse: 3.33959
# Early stopping, best iteration is:
# [2651]	train's rmse: 2.9938	valid's rmse: 3.32734
#
# ------------  END ------------
# CV:  3.4197935609243744

# %%
test_labels.columns = ["id", "pred"]
test_labels = pd.DataFrame(test_labels)

# %%
test_labels.head(2)
# Out:
#      id       pred
# 0  8761  12.415037
# 1  8762  12.415037

# %%
test_labels.shape
# Out:
# (193200, 2)

# %% [markdown]
# # 输出

# %%
submission = test_labels
submission.to_csv("advanced4_2.csv",index=False, header=False)

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193200 entries, 0 to 16099
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      193200 non-null  int64
#  1   pred    193200 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 4.4 MB

# %%
# train["text"].map(lambda x: len(x)).describe()
